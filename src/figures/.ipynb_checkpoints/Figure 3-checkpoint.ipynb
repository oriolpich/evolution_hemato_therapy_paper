# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../analysis/")

# %% [markdown]
# # 3A

# %% [markdown]
# # 3B

# %%
sys.path.append("../signatures/")

from profiles import plot_snvs

# %%
d = '/workspace/projects/reverse_calling/data/signatures_2020/boxtel.snvs.tsv'
outpath = "fig3/"
hcss = ['AC41HSC3', 'AC63HSCc2', 
       'ACC55HSC15','ACHSC19', 'ACHSC23',
        'ACHSC7', 'ACHSCc6',
       'ACHSCc8','BCHHSC4']
df = pd.read_csv(d, sep ='\t')
mean_counts = df[hcss].mean(axis = 1)
normalized = mean_counts/mean_counts.sum()

plot_snvs(normalized, "HSC", outpath )

# %% [markdown]
# # 3C

# %%
import sys
import pandas as pd 
import json

sys.path.append("../analysis/")

from age_corr import do_plot

# %%
exp = '/workspace/projects/reverse_calling/data/signatures_2020/SigProfiler/results/exposures/AML_all_hemato.snvs/AML_all_hemato.snvs.exposures.tsv'
df_exp = pd.read_csv(exp, sep ='\t', index_col = 0).T
exposures = df_exp[df_exp['2_0.97_NA']>0]

high_mut_platinum = ['AP0390_AP0395', 'AP0388_AP0389', 'SRR1802228_SRR1800776', 'SRR388810_SRR388850', 
                    'SRR1802754_SRR1802621', 'PATIENT_WTS_1_TUM1_PATIENT_WTS_1_BUC', 'PATIENT_WTS_3_TUM1_PATIENT_WTS_3_BUC'
                    'SRR1802711_SRR1802494']

outpath = "fig3/"

dic_samples_ttypes = json.load(open('/workspace/projects/reverse_calling/data/samples/list_ttype.json'))
dic_aging_sample_level = json.load(open('/workspace/projects/reverse_calling/data/samples/sample_2_age.json'))

meta_hsc = pd.read_csv('/workspace/projects/all_aecc/Osorio_data/metadata_samples.txt', sep ='\t')
dic_HSC = dict(zip(meta_hsc['Identifier'], meta_hsc['Age (years)']))

# %%
do_plot(exposures.T.loc[['2_0.97_NA']], 'SigProfiler', high_mut_platinum, outpath, 
       dic_samples_ttypes, dic_aging_sample_level, dic_HSC)
# Out:
# tAML pval 0.8191102481615107 R 0.05325771192963786 Slope 1.309896466964915
# Primary pval 2.3493024728551427e-11 R 0.8510432635113883 Slope 16.218202774295307
# HSC Boxtel pval 2.860272745650192e-17 R 0.9049457210414374 Slope 11.16588651273646 intercept 47.89659299876362

# %% [markdown]
# # 3D

# %%
from beatAML import do_barplot

# %%
# this is from CBIOPORTAL, even though the intogen run was done using the raw data because cbioportal does 
# not have synonymous mutations
mutations_beatAML = "/workspace/datasets/reverse_calling/OHSU_2018/new/data_mutations_extended.txt"
clinical_data = "/workspace/datasets/reverse_calling/OHSU_2018/new/data_clinical_sample.txt"
drivers_AML = "/home/opich/bg/tAML_code_review/evolution_hemato_therapy/src/analysis/AML_intogen.tsv"
outpath = "fig3/"

do_barplot(mutations_beatAML, clinical_data, drivers_AML, outpath)
# Out:
# /home/opich/anaconda3/envs/healthy/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# # 3F

# %%
from beatAML import odds_ratio_tAMLs

# %%
# this is from CBIOPORTAL, even though the intogen run was done using the raw data because cbioportal does 
# not have synonymous mutations
mutations_beatAML = "/workspace/datasets/reverse_calling/OHSU_2018/new/data_mutations_extended.txt"
clinical_data = "/workspace/datasets/reverse_calling/OHSU_2018/new/data_clinical_sample.txt"
drivers_AML = "/home/opich/bg/tAML_code_review/evolution_hemato_therapy/src/analysis/AML_intogen.tsv"
outpath = "fig3/"


odds_ratio_tAMLs(mutations_beatAML, clinical_data, drivers_AML, outpath)
# Out:
# /home/opich/anaconda3/envs/healthy/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# # Supplementary Figures

# %% [markdown]
# ## 3D

# %%
import sys
import pandas as pd 
import json



from beatAML import do_heatmap

# %%
# this is from CBIOPORTAL, even though the intogen run was done using the raw data because cbioportal does 
# not have synonymous mutations
mutations_beatAML = "/workspace/datasets/reverse_calling/OHSU_2018/new/data_mutations_extended.txt"
clinical_data = "/workspace/datasets/reverse_calling/OHSU_2018/new/data_clinical_sample.txt"
drivers_AML = "/home/opich/bg/tAML_code_review/evolution_hemato_therapy/src/analysis/AML_intogen.tsv"
outpath = "fig3/"

# %%
do_heatmap(mutations_beatAML, clinical_data, drivers_AML, outpath)
